# %%
# !pip install bing-image-downloader
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\muhri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\muhri\anaconda3\lib\site-packages)

# %%
from bing_image_downloader import downloader

labels = ['black', 'blue', 'brown', 'green', 'pink', 'red', 'silver', 'white', 'yellow']

for label in labels:
    downloader.download(f"{label} color object items", limit=100,  output_dir=f'dataset/{label}', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to c:\Users\muhri\Untitled Folder 1\ML\Modeling\color detection\new\dataset\black\black color object items
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img0.etsystatic.com/000/0/6907588/il_570xN.343523436.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://2.bp.blogspot.com/-p1DX88IPBqs/U9QbgZlep_I/AAAAAAAABNk/604ehg4lExA/s1600/HC1414.jpg_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.kindpng.com/picc/m/648-6489844_black-colour-objects-clipart-hd-png-download.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://clipart-library.com/images/piodbbBET.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://clipart-library.com/images/zcX5BB9qi.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/XWRj4xX4Zic/maxresdefault.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# ## Adding imports

# %%
import os
from PIL import Image

# %% [markdown]
# ## Checking any corrupt file and deleting it

# %%
def sanitize_images(root_dir):
    color_dirs = ['black', 'blue', 'brown', 'green', 'pink', 'red', 'silver', 'white', 'yellow']
    for color_dir in color_dirs:
        dir_path = os.path.join(root_dir, color_dir)
        for subdir, dirs, files in os.walk(dir_path):
            for file in files:
                file_path = os.path.join(subdir, file)
                try:
                    with Image.open(file_path) as img:  # open the image file
                        img.verify()  # verify that it is, in fact, an image
                except (IOError, SyntaxError) as e:
                    print('Bad file:', file_path)  # print out the names of corrupt files
                    os.remove(file_path)  # remove the corrupt image

sanitize_images('dataset/train/')
# Out:
# Bad file: dataset/train/brown\Image_25.jpg
# Bad file: dataset/train/green\Image_33.jpg
# Bad file: dataset/train/pink\Image_47.jpg
# Bad file: dataset/train/yellow\Image_2.jpg
# Bad file: dataset/train/yellow\Image_26.jpg
# Bad file: dataset/train/yellow\Image_29.jpg
